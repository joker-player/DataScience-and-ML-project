# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
df  = pd.read_csv("/content/data.csv")
df.shape
# Out:
# (569, 33)

# %%
df.head()
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df["diagnosis"] = df["diagnosis"].map({ 'M': 1 , 'B' : 0}).astype(int)

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df['Unnamed: 32']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 564   NaN
# 565   NaN
# 566   NaN
# 567   NaN
# 568   NaN
# Name: Unnamed: 32, Length: 569, dtype: float64

# %%
df2 = df.drop('Unnamed: 32',axis='columns')
df2.head()
# Out:
#          id  diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0    842302          1  ...          0.4601                  0.11890
# 1    842517          1  ...          0.2750                  0.08902
# 2  84300903          1  ...          0.3613                  0.08758
# 3  84348301          1  ...          0.6638                  0.17300
# 4  84358402          1  ...          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
x = df2.drop("diagnosis" ,axis='columns' )
y = df2.diagnosis

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
from sklearn.model_selection import StratifiedKFold

# %%
model = []
model.append(['LR',LinearRegression()])
model.append(['LOR',LogisticRegression()])
model.append(['Tr',DecisionTreeClassifier()])
model.append(['svm',SVC()])

# %%
result = []
names = []
res = []
for name,models in model:
  kfold = StratifiedKFold(n_splits=10 )
  cv_result = cross_val_score(models,X_train,y_train,cv =kfold )
  result.append(cv_result)
  names.append(name)
  res.append(cv_result.mean())
  print("%s: %f", (name ,cv_result.mean()))


plt.bar(names,res)
# Out:
# %s: %f ('LR', 0.7339169802589324)
# %s: %f ('LOR', 0.9823188405797101)
# %s: %f ('Tr', 0.9210628019323671)
# %s: %f ('svm', 0.9736231884057972)
# <BarContainer object of 4 artists>

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
from sklearn.svm import SVC
model1 = SVC()
model1.fit(X_train,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
